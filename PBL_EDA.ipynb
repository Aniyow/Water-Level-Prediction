# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

sns.set_style("whitegrid")

# %%
df1=pd.read_csv("ground_water_quality_2018_post.csv")
df2=pd.read_csv("ground_water_quality_2020_post.csv")
df3=pd.read_csv("ground_water_quality_2020_post.csv")
df4=pd.read_csv("ground_water_quality_2018_post.csv")
df5=pd.read_csv("ground_water_quality_2018_post.csv")

# %%
df=pd.concat([df1,df2,df3,df4,df5],axis=0)

# %%
df
# Out:
#      sno  district        mandal       village    lat_gis   long_gis    gwl  \
# 0      1  ADILABAD      Adilabad      Adilabad  19.668300  78.524700   5.09
# 1      2  ADILABAD   Bazarhatnur   Bazarhatnur  19.458888  78.350833   5.10
# 2      3  ADILABAD   Gudihatnoor   Gudihatnoor  19.525555  78.512222   4.98
# 3      4  ADILABAD       Jainath       Jainath  19.730555  78.640000   5.75
# 4      5  ADILABAD       Narnoor       Narnoor  19.495665  78.852654   2.15
# ..   ...       ...           ...           ...        ...        ...    ...
# 369  375   YADADRI  S.Narayanpur  S.Narayanpur  17.144719  78.860010  25.46
# 370  376   YADADRI   Thurkapally    Gandamalla  17.733101  78.853831   8.39
# 371  377   YADADRI     Valigonda    T. somaram  17.399953  78.952290  21.21
# 372  378   YADADRI     Valigonda   Vemulakonda  17.347782  79.143433   4.54
# 373  379   YADADRI       Y.Gutta    Mallapuram  17.633555  78.911638  30.15
#
# ...

# %%
sns.scatterplot(x="lat_gis",y="long_gis",hue="Na",data=df)
# Out:
# <Axes: xlabel='lat_gis', ylabel='long_gis'>

# %%
sns.scatterplot(x="lat_gis",y="long_gis",hue="gwl",data=df)
# Out:
# <Axes: xlabel='lat_gis', ylabel='long_gis'>

# %%
sns.jointplot(x="gwl",y="pH",data=df,kind='hex')
